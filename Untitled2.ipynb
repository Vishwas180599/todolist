# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishwas180599/todolist/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#description :this program artificial RNN
#to predict using 
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf
import datetime
from keras.models import load_model
from keras.models import load_model
from keras import models 
import keras
model = keras.models.load_model('keras_model.h5')
model.save('keras_model.h5')

# %%
import tensorflow.compat.v2 as tf
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.2

# %%
import yfinance as yf
df = yf.download('BTC-USD', start='2010-01-01', end='2019-12-31')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-27  7238.141113  7363.529297  7189.934082  7290.088379  7290.088379
# 2019-12-28  7289.031250  7399.041016  7286.905273  7317.990234  7317.990234
# 2019-12-29  7317.647461  7513.948242  7279.865234  7422.652832  7422.652832
# 2019-12-30  7420.272949  7454.824219  7276.308105  7292.995117  7292.995117
# 2019-12-31  7294.438965  7335.290039  7169.777832  7193.599121  7193.599121
#
#                  Volume
# Date
# 2019-12-27  22777360996
# 2019-12-28  21365673026
# 2019-12-29  22445257702
# 2019-12-30  22874131672
# 2019-12-31  21167946112

# %%
df = df.reset_index()
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
plt.plot(df.Close)

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2014-09-17   465.864014   468.174011   452.421997   457.334015
# 1    2014-09-18   456.859985   456.859985   413.104004   424.440002
# 2    2014-09-19   424.102997   427.834991   384.532013   394.795990
# 3    2014-09-20   394.673004   423.295990   389.882996   408.903992
# 4    2014-09-21   408.084991   412.425995   393.181000   398.821014
# ...         ...          ...          ...          ...          ...
# 1927 2019-12-27  7238.141113  7363.529297  7189.934082  7290.088379
# 1928 2019-12-28  7289.031250  7399.041016  7286.905273  7317.990234
# 1929 2019-12-29  7317.647461  7513.948242  7279.865234  7422.652832
# 1930 2019-12-30  7420.272949  7454.824219  7276.308105  7292.995117
# 1931 2019-12-31  7294.438965  7335.290039  7169.777832  7193.599121
#
#         Adj Close       Volume
# 0      457.334015     21056800
# 1      424.440002     34483200
# 2      394.795990     37919700
# ...

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 1927    8169.439756
# 1928    8139.955508
# 1929    8112.365620
# 1930    8085.098403
# 1931    8056.330469
# Name: Close, Length: 1932, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 1927    9327.934119
# 1928    9324.885498
# 1929    9321.269475
# 1930    9316.579832
# 1931    9309.078662
# Name: Close, Length: 1932, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape
# Out:
# (1932, 7)

# %%
# Splitting data into Training and Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1352, 1)
# (580, 1)

# %%
data_training.head()
# Out:
#         Close
# 0  457.334015
# 1  424.440002
# 2  394.795990
# 3  408.903992
# 4  398.821014

# %%
data_testing.head()
# Out:
#             Close
# 1352  7494.169922
# 1353  7541.450195
# 1354  7643.450195
# 1355  7720.250000
# 1356  7514.470215

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.01445348],
#        [0.01275083],
#        [0.0112164 ],
#        ...,
#        [0.36015219],
#        [0.37757516],
#        [0.37415527]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
#ML model

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
              input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))




model.add(LSTM(units = 60, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.3))




model.add(LSTM(units = 80, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.4))




model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))



model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_4 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_5 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_6 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_7 (LSTM)               (None, 120)               96480
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 22s 439ms/step - loss: 0.0173
# Epoch 2/50
# 40/40 [==============================] - 20s 491ms/step - loss: 0.0061
# Epoch 3/50
# 40/40 [==============================] - 11s 266ms/step - loss: 0.0066
# Epoch 4/50
# 40/40 [==============================] - 11s 282ms/step - loss: 0.0048
# Epoch 5/50
# 40/40 [==============================] - 11s 271ms/step - loss: 0.0050
# Epoch 6/50
# 40/40 [==============================] - 11s 267ms/step - loss: 0.0047
# Epoch 7/50
# 40/40 [==============================] - 11s 268ms/step - loss: 0.0042
# Epoch 8/50
# 40/40 [==============================] - 12s 294ms/step - loss: 0.0044
# Epoch 9/50
# 40/40 [==============================] - 11s 269ms/step - loss: 0.0039
# Epoch 10/50
# 40/40 [==============================] - 11s 268ms/step - loss: 0.0041
# Epoch 11/50
# 40/40 [==============================] - 12s 289ms/step - loss: 0.0033
# Epoch 12/50
# ...

# %%
model.save('keras_model.h5')

# %%
data_testing.head()
# Out:
#             Close
# 1352  7494.169922
# 1353  7541.450195
# 1354  7643.450195
# 1355  7720.250000
# 1356  7514.470215

# %%
data_testing.tail(100)
# Out:
#             Close
# 1832  9729.324219
# 1833  8620.566406
# 1834  8486.993164
# 1835  8118.967773
# 1836  8251.845703
# ...           ...
# 1927  7290.088379
# 1928  7317.990234
# 1929  7422.652832
# 1930  7292.995117
# 1931  7193.599121
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
final_df = past_100_days.append(data_testing, ignore_index=True)

# %%
final_df.head()
# Out:
#           Close
# 0  11403.700195
# 1  10690.400391
# 2  10005.000000
# 3  10301.099609
# 4   9813.070312

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[8.35110564e-01],
#        [7.62172069e-01],
#        [6.92086429e-01],
#        [7.22364104e-01],
#        [6.72460653e-01],
#        [6.57292157e-01],
#        [7.29072094e-01],
#        [7.65771366e-01],
#        [7.32262471e-01],
#        [7.88819690e-01],
#        [8.02665062e-01],
#        [8.43904497e-01],
#        [8.46246077e-01],
#        [8.52452977e-01],
#        [7.71323894e-01],
#        [6.88054545e-01],
#        [6.29711857e-01],
#        [6.23836287e-01],
#        [5.75617946e-01],
#        [6.48487939e-01],
#        [6.10294685e-01],
#        [6.09244474e-01],
#        [5.14654474e-01],
#        [5.17829573e-01],
#        [5.21663038e-01],
#        [4.78565637e-01],
#        [5.09937462e-01],
#        [5.51552264e-01],
#        [5.80471965e-01],
#        [5.82088673e-01],
#        [5.61554784e-01],
#        [5.77010672e-01],
#        [5.55383732e-01],
#        [5.37761116e-01],
#        [5.08477332e-01],
#        [4.69992592e-01],
#        [4.82410437e-01],
# ...

# %%
input_data.shape
# Out:
# (680, 1)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]): 
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (580, 100, 1)
# (580,)

# %%
# Making Predictions

y_predicted = model.predict(x_test)

# %%
y_predicted.shape
# Out:
# (580, 1)

# %%
y_test
# Out:
# array([4.35341416e-01, 4.40176062e-01, 4.50606076e-01, 4.58459242e-01,
#        4.37417224e-01, 4.49615181e-01, 4.51682799e-01, 4.54163532e-01,
#        4.48711262e-01, 4.39207685e-01, 3.62929525e-01, 3.75292148e-01,
#        3.42104249e-01, 3.18334048e-01, 3.51612968e-01, 3.29242633e-01,
#        3.38811667e-01, 3.33607894e-01, 3.57694047e-01, 3.61285256e-01,
#        3.61961148e-01, 3.57174634e-01, 2.91112739e-01, 2.99169418e-01,
#        3.00268659e-01, 3.08034949e-01, 2.92133243e-01, 2.98622343e-01,
#        2.72681270e-01, 3.04877275e-01, 3.23866055e-01, 3.22007041e-01,
#        3.45358036e-01, 3.36708249e-01, 3.43657497e-01, 3.47910318e-01,
#        3.51423786e-01, 3.70180445e-01, 3.61688135e-01, 3.58402693e-01,
#        3.16294090e-01, 3.22916102e-01, 3.05952002e-01, 3.06896812e-01,
#        3.10789693e-01, 3.19330036e-01, 3.58402693e-01, 4.17638015e-01,
#        4.22724154e-01, 4.32548826e-01, 4.21021618e-01, 4.27684572e-01,
# ...

# %%
y_predicted
# Out:
# array([[0.36281505],
#        [0.35662812],
#        [0.35190493],
#        [0.34890154],
#        [0.3477441 ],
#        [0.3480299 ],
#        [0.34947255],
#        [0.35178462],
#        [0.35473657],
#        [0.35798103],
#        [0.36102444],
#        [0.36247784],
#        [0.36179823],
#        [0.35868755],
#        [0.35316256],
#        [0.34595138],
#        [0.33765686],
#        [0.32899997],
#        [0.32055718],
#        [0.312989  ],
#        [0.3067715 ],
#        [0.30219635],
#        [0.29923648],
#        [0.2969582 ],
#        [0.29465836],
#        [0.29198915],
#        [0.28896007],
#        [0.28557384],
#        [0.28197995],
#        [0.27811217],
#        [0.27427906],
#        [0.27098584],
#        [0.26858875],
#        [0.26748914],
#        [0.26773563],
#        [0.26923817],
#        [0.2718466 ],
#        [0.27531338],
#        [0.27956074],
#        [0.2843395 ],
#        [0.2892938 ],
#        [0.29355934],
#        [0.29660422],
# ...

# %%
scaler.scale_
# Out:
# array([0.00010226])

# %%
scale_factor = 1/5.17617168e-05
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = 'Original Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # New Section
